# %%
pip install -U plotly pandas
# Out:
# ...
#      |████████████████████████████████| 23.9 MB 1.4 MB/s
# ...
#      |████████████████████████████████| 11.3 MB 44.1 MB/s
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 4.4.1
#     Uninstalling plotly-4.4.1:
#       Successfully uninstalled plotly-4.4.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.3.4 which is incompatible.
# ...

# %%
# !wget http://archive.ics.uci.edu/ml/machine-learning-databases/00275/Bike-Sharing-Dataset.zip
# Out:
# --2021-10-26 01:51:41--  http://archive.ics.uci.edu/ml/machine-learning-databases/00275/Bike-Sharing-Dataset.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 279992 (273K) [application/x-httpd-php]
# Saving to: ‘Bike-Sharing-Dataset.zip’
#
# Bike-Sharing-Datase 100%[===================>] 273.43K   778KB/s    in 0.4s
#
# 2021-10-26 01:51:41 (778 KB/s) - ‘Bike-Sharing-Dataset.zip’ saved [279992/279992]

# %%
# !unzip Bike-Sharing-Dataset.zip
# Out:
# Archive:  Bike-Sharing-Dataset.zip
#   inflating: Readme.txt
#   inflating: day.csv
#   inflating: hour.csv

# %%
import numpy as np
import pandas as pd
pd.set_option("max_rows", 100, "max_colwidth", 100, "max_columns", 100, "display.unicode.east_asian_width", True)
# google colabで使う場合は必須 => pip install -U plotly pandas
pd.options.plotting.backend = "plotly"
pd.options.display.float_format = "{:.4f}".format

import plotly.express as px
import plotly.figure_factory as ff

# %%
df = pd.read_csv("./day.csv", parse_dates=["dteday"])
df.drop(columns=["yr", "mnth"], inplace=True)
df["season"] = df.season.map({1: "冬", 2: "春", 3: "夏", 4: "秋"})
df["holiday"] = df.holiday.map({0: "平日", 1: "休日"})
df["weekday"] = df.weekday.map({0: "月曜日", 1: "火曜日", 2: "水曜日", 3: "木曜日", 4: "金曜日", 5: "土曜日", 6: "日曜日"})
df["weathersit"] = df.weathersit.map({1: "晴れ", 2: "曇り", 3: "小雨", 4: "大雨"})
df.head()
# Out:
#    instant     dteday season holiday weekday  workingday weathersit   temp  \
# 0        1 2011-01-01     冬    平日  日曜日           0       曇り 0.3442
# 1        2 2011-01-02     冬    平日  月曜日           0       曇り 0.3635
# 2        3 2011-01-03     冬    平日  火曜日           1       晴れ 0.1964
# 3        4 2011-01-04     冬    平日  水曜日           1       晴れ 0.2000
# 4        5 2011-01-05     冬    平日  木曜日           1       晴れ 0.2270
#
#    atemp    hum  windspeed  casual  registered   cnt
# 0 0.3636 0.8058     0.1604     331         654   985
# 1 0.3537 0.6961     0.2485     131         670   801
# 2 0.1894 0.4373     0.2483     120        1229  1349
# 3 0.2121 0.5904     0.1603     108        1454  1562
# 4 0.2293 0.4370     0.1869      82        1518  1600

# %%
df.dteday.min(), df.dteday.max()

# %% [markdown]
# ### ヒストグラム

# %%
df.plot.hist(x="cnt")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.weathersit.plot.hist()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 
df.cnt.plot.hist(title="自転車レンタル数のヒストグラム", labels={"value": "レンタル数", "count": "回数"})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.plot.hist(x="cnt", color="weathersit", barmode="group") # barmodeにはstack, overlayなども指定可能
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 棒グラフ

# %%
df.weathersit.value_counts().reset_index().plot.bar(x="index", y="weathersit", title="気候の集計", labels={"index": "気候", "weathersit":"日数"}, color=['#7f7f7f', '#7f7f7f', "red"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.plot.bar(x="dteday", y="cnt")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.set_index("dteday").plot.bar(y="cnt")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.set_index("dteday").resample("M").cnt.sum().plot.bar()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = df.set_index("dteday").resample("M").agg({"cnt": "sum", "season": "max"}).plot.bar(y="cnt", color="season")

# %%
fig.update_coloraxes
# Out:
# <bound method Figure.update_coloraxes of Figure({
#     'data': [{'alignmentgroup': 'True',
#               'hovertemplate': 'season=冬<br>dteday=%{x}<br>cnt=%{y}<extra></extra>',
#               'legendgroup': '冬',
#               'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#               'name': '冬',
#               'offsetgroup': '冬',
#               'orientation': 'v',
#               'showlegend': True,
#               'textposition': 'auto',
#               'type': 'bar',
#               'x': array([datetime.datetime(2011, 1, 31, 0, 0),
#                           datetime.datetime(2011, 2, 28, 0, 0),
#                           datetime.datetime(2012, 1, 31, 0, 0),
#                           datetime.datetime(2012, 2, 29, 0, 0)], dtype=object),
#               'xaxis': 'x',
#               'y': array([ 38189,  48215,  96744, 103137]),
#               'yaxis': 'y'},
#              {'alignmentgroup': 'True',
# ...

# %%
# 月次集計
df.set_index("dteday").resample("M")[["casual", "registered"]].sum().plot.bar(barmode="group")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 月次集計
df.set_index("dteday").resample("M")[["casual", "registered"]].sum().plot.bar()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_month.plot.bar(barmode="group") # y=["casual", "registered"]は無くてもOK!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-4c645b307211> in <module>()
# ----> 1 df_month.plot.bar(barmode="group") # y=["casual", "registered"]は無くてもOK!
#
# NameError: name 'df_month' is not defined

# %%
df_tate = df.melt(
    id_vars=['instant','dteday', 'season', 'holiday', 'weekday',
                'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed'],
    value_vars=["casual", "registered"],
    var_name="userkind",
    value_name="count").sort_values(by=["dteday", "userkind"])

# %%
df_tate.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-0fa8c007ed33> in <module>()
# ----> 1 df_tate.head(10)
#
# NameError: name 'df_tate' is not defined

# %%
df_tate.groupby("userkind").apply(lambda g: g.set_index("dteday").resample("M").agg({"count": "mean"})) \
.reset_index("userkind").plot.bar(color="userkind", barmode="group")

# %%
df.season.value_counts(ascending=True).plot.barh()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 散布図

# %%
df.plot.scatter(x="temp", y="cnt", opacity=0.5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.plot.scatter(x="temp", y="atemp", opacity=0.3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.corr().round(3).plot(kind="imshow")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
corr_df = df.corr().round(3)
ff.create_annotated_heatmap(corr_df.values, x=corr_df.index.to_list(), y=corr_df.columns.to_list(), colorscale='Greys')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.pie(df, values="cnt", names="weekday")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 箱ひげず

# %%
df.cnt.plot.box()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.plot.box(x="season", y="cnt")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.plot(x="season", y="cnt", kind="violin", color="season")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 線

# %%
df.plot.line(x="dteday", y="cnt")

# %%
df.set_index("dteday").plot.line(y=["casual", "registered"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.rolling?

# %%
df.set_index("dteday")[["casual", "registered"]].rolling(window=30, center=True).mean().plot.line()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 少しよく見せたい

# %%
df.groupby("weekday").cnt.sum().sort_values().plot.barh()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.groupby("weekday").cnt.sum().sort_values().plot.barh(
    title="曜日ごとのレンタル合計数",
    labels={"value": "レンタル数", "weekday": "曜日"},
    text="value")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
