# %%
# !pip install transformers fugashi
# Out:
# ...
#      |████████████████████████████████| 490 kB 37.4 MB/s
# ...

# %%
from transformers import BertJapaneseTokenizer

# %%
bert_tk = BertJapaneseTokenizer.from_pretrained("cl-tohoku/bert-base-japanese-whole-word-masking")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert_japanese/tokenization_bert_japanese.py in __init__(self, do_lower_case, never_split, normalize_text, mecab_dic, mecab_option)
#     242                 try:
# --> 243                     import ipadic
#     244                 except ModuleNotFoundError as error:
#
# ModuleNotFoundError: No module named 'ipadic'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-bd6a80c2dd4a> in <module>()
# ----> 1 bert_tk = BertJapaneseTokenizer.from_pretrained("cl-tohoku/bert-base-japanese-whole-word-masking")
#
# ...

# %%
tmp_text = "これは、データサイエンティストとして、「知らなかった」では済まされません。"

# %%
tagger.parse(tmp_text)

# %%
s = map(int, list("100"))

# %%
sum(s)
# Out:
# 1
