# %%
# Huggingface Transformersのインストール
# !pip install transformers==4.4.2

# Sentencepieceのインストール
# !pip install sentencepiece==0.1.91
# Out:
# ...
#      |████████████████████████████████| 2.0 MB 4.1 MB/s
# ...
#      |████████████████████████████████| 895 kB 54.7 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 39.6 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 4.2 MB/s
# ...

# %%
from transformers import T5Tokenizer, AutoModelForCausalLM

# トークナイザーとモデルの準備
tokenizer = T5Tokenizer.from_pretrained("rinna/japanese-gpt2-medium")
model = AutoModelForCausalLM.from_pretrained("rinna/japanese-gpt2-medium")
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Input length of input_ids is 138, but ``max_length`` is set to 30.This can lead to unexpected behavior. You should consider increasing ``config.max_length`` or ``max_length``.
# ...

# %%
# 推論
text = "19日に新型コロナウイルスに感染したことが明らかとなったお笑いトリオ・安田大サーカスのクロちゃん（44）が21日、自身のTwitterを更新。入院していることを明らかにした。【写真】クロちゃんが一目惚れした美人トレーナーが「可愛すぎる」と話題◆クロちゃん「どんなコメントでも元気が出ます」クロちゃんは「今は、入院してコロナの治療をしていただいてます」と報告。「1日も早く元気なカラダに戻れるように努めます」とした。そして、SNS上で寄せられているメッセージに「たくさんのメッセージありがとうございます。どんなコメントでも元気が出ます。ありがとう」と感謝している。"
input = tokenizer.encode(text, return_tensors="pt")
output = model.generate(input, do_sample=True, max_length=1000, num_return_sequences=3)
print(tokenizer.batch_decode(output))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# ...

# %%
tokenizer.get_vocab()
# Out:
# 32000
